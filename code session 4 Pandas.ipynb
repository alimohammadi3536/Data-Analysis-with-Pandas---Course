# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# In[1]:

# %%
import pandas as pd

# %% [markdown]
# In[2]:

# %%
a=pd.read_csv('C:\\Users\\Ali\\Desktop\\dataset session (1,2 ) Pandas  weather.csv',usecols=['play'],squeeze=True)
a.head(3)

# %% [markdown]
# In[18]:

# %%
5 in a

# %% [markdown]
# In[21]:

# %%
13 in a.index

# %% [markdown]
# In[22]:

# %%
13 in a

# %% [markdown]
# In[24]:

# %%
a.values
'yes' in a

# %% [markdown]
# In[19]:

# %%
a.index

# %% [markdown]
# In[25]:

# %%
"yes" in a.values

# %% [markdown]
# In[8]:

# %%
a

# %% [markdown]
# In[ ]:

# %%
3 in [3,6,9]

# %% [markdown]
# In[ ]:

# %%
100 in [3,6,9]

# %% [markdown]
# In[3]:

# %%
a[0]

# %% [markdown]
# In[4]:

# %%
a[[0,8,9]]

# %% [markdown]
# In[5]:

# %%
a[1:3]

# %% [markdown]
# In[7]:

# %%
a[-3:]

# %% [markdown]
# In[9]:

# %%
a[-1:]

# %% [markdown]
# In[10]:

# %%
a[:3]

# %% [markdown]
# In[16]:

# %%
a[-5:-1]

# %% [markdown]
# In[ ]:

# %% [markdown]
# In[ ]:
